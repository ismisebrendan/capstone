# %%
import numpy as np
import sys
import os
import matplotlib.pyplot as plt

spec_path = os.path.abspath('..') + '\\Spectrum_Obj'
sys.path.insert(0, spec_path)

from spectrum_obj import Spectrum

# %%
spec = Spectrum('../False_Pos_Detection/lines_in/lines_in_LINER.txt', '../False_Pos_Detection/fitting/fitting_LINER.txt', Nsim=1, AoN_min=10)

spec.simulation(plotting=True)
